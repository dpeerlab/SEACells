# %%
import numpy as np
import pandas as pd

import scanpy as sc

from importlib import reload
import sys
import os
sys.path.insert(1, os.path.join(sys.path[0], '..'))

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
import benchmark_utils as bm

# %% [markdown]
# # Load Data
#
# We recommend the use of scanpy Anndata objects as the preferred mode of loading and filtering data.
#
# A sample dataset is provided and can be accessed using the ```load_data()``` method

# %%
from src.metacells.utils import load_data
# Out:
# findfont: Font family ['Raleway'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Lato'] not found. Falling back to DejaVu Sans.

# %%
ad = load_data()

# %% [markdown]
# # Pre-processing
#
# todo

# %% [markdown]
# # Running Metacells

# %%
## User defined parameters

## Core parameters 
n_metacells = 10
build_kernel_on = 'X_pca' # key in ad.obsm to use for computing metacells

## Additional parameters
n_waypoint_eigs = 10 # Number of eigenvalues to consider when initializing metacells
waypoint_proportion = 1 # Proportion of metacells to initialize using waypoint analysis, 
                        # the remainder of cells are selected by greedy selection

# %%
from src.metacells.core import Metacells
from sklearn.metrics import silhouette_score


model = Metacells(ad, 
                  build_kernel_on=build_kernel_on, 
                  n_metacells=n_metacells, 
                  n_waypoint_eigs=n_waypoint_eigs)

model.fit(n_iter=8)
# Out:
# Building kernel...
# Computing kNN graph using scanpy NN ...
# Computing radius for adaptive bandwidth kernel...
# HBox(children=(IntProgress(value=0, max=350), HTML(value='')))
# Making graph symmetric...
# Computing RBF kernel...
# HBox(children=(IntProgress(value=0, max=350), HTML(value='')))
# Building similarity LIL matrix...
# HBox(children=(IntProgress(value=0, max=350), HTML(value='')))
# Constructing CSR matrix...
# Computing diffusion components from X_pca for waypoint initialization ...
# Determing nearest neighbor graph...
# Done.
# Sampling waypoints ...
# Done.
# Initializing residual matrix using greedy column selection
# Initializing f and g...
# HBox(children=(IntProgress(value=0, max=11), HTML(value='')))
# Selecting 9 cells from waypoint initialization.
# Selecting 1 cells from greedy initialization.
# Starting iteration 1 of 8
# Completed iteration 1 of 8.
# Starting iteration 2 of 8
# Completed iteration 2 of 8.
# Starting iteration 3 of 8
# Completed iteration 3 of 8.
# Starting iteration 4 of 8
# Completed iteration 4 of 8.
# Starting iteration 5 of 8
# Completed iteration 5 of 8.
# Starting iteration 6 of 8
# Completed iteration 6 of 8.
# Starting iteration 7 of 8
# Completed iteration 7 of 8.
# Starting iteration 8 of 8
# Completed iteration 8 of 8.

# %% [markdown]
# # Accessing results

# %%
model.get_assignments()
# Out:
#                                                                  metacell_ID
# index
# cd34_multiome_rep1#AAACAGCCACTCGCTC-1  cd34_multiome_rep2#TGCTCAACACAACAAA-1
# cd34_multiome_rep1#AAACAGCCACTGACCG-1  cd34_multiome_rep2#TTTGAGTCAACAGCCT-1
# cd34_multiome_rep1#AAACAGCCATAATCAC-1  cd34_multiome_rep2#TTAACTGAGCAAGACA-1
# cd34_multiome_rep1#AAACATGCAAATTCGT-1  cd34_multiome_rep2#TTAACTGAGCAAGACA-1
# cd34_multiome_rep1#AAACATGCAGCATGTC-1  cd34_multiome_rep2#TGTGCACCAAAGCCTC-1
# ...                                                                      ...
# cd34_multiome_rep2#TTTGTCTAGGGCCACT-1  cd34_multiome_rep2#TTCCCGCCATAAGTCT-1
# cd34_multiome_rep2#TTTGTGAAGGAAGCAC-1  cd34_multiome_rep2#TTAACTGAGCAAGACA-1
# cd34_multiome_rep2#TTTGTGAAGTAACCAC-1  cd34_multiome_rep2#TTCCCGCCATAAGTCT-1
# cd34_multiome_rep2#TTTGTGGCATACTCCT-1  cd34_multiome_rep2#TGTGCACCAAAGCCTC-1
# cd34_multiome_rep2#TTTGTTGGTTCGCTCA-1  cd34_multiome_rep2#TGCTCAACACAACAAA-1
#
# [6881 rows x 1 columns]

# %% [markdown]
# # Visualizing Results
#
# PKG also implements methods for visualizing the results of the Metacells algorithm
#     <ul>
#         <li>```.plot_2D``` provides an interface for viewing metacell assignments on any 2-dimensional embedding in ad.obsm. Plots can also be coloured by metacell assignment.
#         <li>```.plot_metacell_sizes``` can be used to view the distribution of number of cells assigned to each metacell
#     </ul>

# %%
# Load the plotting functionality
import src.metacells.plot as plot

# %%
plot.plot_2D(ad, key='X_umap', colour_metacells=False)

# %%
plot.plot_2D(ad, key = 'X_FDL', colour_metacells=True)

# %%
plot.plot_metacell_sizes(ad)
# Out:
# /Users/sitarapersad/opt/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Evaluate metacell results

# %%
from src.metacells import evaluate
reload(evaluate)
# Out:
# <module 'src.metacells.evaluate' from '/Users/sitarapersad/metacells/notebooks/../src/metacells/evaluate.py'>

# %%
nbrs, nlls = evaluate.get_NLLs(ad)
# Out:
# Computing 5 neighbours in diffusion component space and Gaussian from X_pca space.
# Determing nearest neighbor graph...
# Clipping to metacells with at least 3 cells.
# Dropping 0 metacell(s) due to insufficient size.
# Clipping to metacells with at least 3 cells.
# Dropping 0 metacell(s) due to insufficient size.
# Computing 5 neighbours in diffusion component space and Gaussian from X_pca space.
# Determing nearest neighbor graph...

# %%
nbrs_f, nlls_f = evaluate.filter_neighbours(nbrs, nlls, cluster='celltype')

# %%
evaluate.plot_compactness(nlls_f)

# %%
evaluate.plot_separation(nlls_f)
# Out:
# /Users/sitarapersad/metacells/notebooks/../src/metacells/evaluate.py:234: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()
